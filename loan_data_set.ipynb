# %%
import pandas as pd
a=pd.read_csv("loan_data_set.csv")

# %%
a
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
a["Loan_ID"].nunique()
# Out:
# 614

# %%
a["LoanAmount"].min()
# Out:
# 9.0

# %%
a["LoanAmount"].max()
# Out:
# 700.0

# %%
a["Gender"].value_counts(normalize=True)*100
# Out:
# Male      81.364393
# Female    18.635607
# Name: Gender, dtype: float64

# %%
a["Loan_Status"].value_counts(normalize=True)*100
# Out:
# Y    68.729642
# N    31.270358
# Name: Loan_Status, dtype: float64

# %%
a["ApplicantIncome"].value_counts(normalize=True)*100
# Out:
# 2500    1.465798
# 4583    0.977199
# 6000    0.977199
# 2600    0.977199
# 3333    0.814332
#           ...
# 3244    0.162866
# 4408    0.162866
# 3917    0.162866
# 3992    0.162866
# 7583    0.162866
# Name: ApplicantIncome, Length: 505, dtype: float64

# %%
a["ApplicantIncome"].value_counts() # not any good insight
# Out:
# 2500    9
# 4583    6
# 6000    6
# 2600    6
# 3333    5
#        ..
# 3244    1
# 4408    1
# 3917    1
# 3992    1
# 7583    1
# Name: ApplicantIncome, Length: 505, dtype: int64

# %%
a["Loan_Status"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
a["Loan_Status"].value_counts().plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
a["Loan_Status"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Loan_Status'>

# %%
a["Gender"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
a["LoanAmount"].max()
# Out:
# 700.0

# %%
a["LoanAmount"].max()
# Out:
# 700.0

# %%
a["Gender"].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
a["LoanAmount"].max()-a["LoanAmount"].min()
# Out:
# 691.0

# %%
a[a["LoanAmount"]==700]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 171  LP001585    NaN     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 171            51763                0.0       700.0             300.0
#
#      Credit_History Property_Area Loan_Status
# 171             1.0         Urban           Y

# %%
a["Loan_Status"].value_counts().plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
a["Loan_Status"].value_counts().plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
a["Loan_Status"].value_counts().plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pd.crosstab(a["Gender"],a["Loan_Status"])
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %%
pd.crosstab(a["Gender"],a["Loan_Status"],normalize="index")*100
# Out:
# Loan_Status          N          Y
# Gender
# Female       33.035714  66.964286
# Male         30.674847  69.325153

# %%
pd.crosstab(a["Gender"],a["Loan_Status"],normalize="columns")*100
# Out:
# Loan_Status          N          Y
# Gender
# Female       19.786096  18.115942
# Male         80.213904  81.884058

# %%
pd.crosstab(a["Gender"],a["Loan_Status"],normalize="index")*100
# Out:
# Loan_Status          N          Y
# Gender
# Female       33.035714  66.964286
# Male         30.674847  69.325153

# %%
pd.crosstab(a["Gender"],a["Loan_Status"]).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
pd.crosstab(a["Gender"],a["Loan_Status"],normalize="index").plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
pd.crosstab(a["Gender"],a["Loan_Status"]).plot(kind="line")
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
pd.crosstab(a["Gender"],a["Loan_Status"]).plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
a["Applicant_in_USD"]=a["ApplicantIncome"]*82

# %%
a.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
# Applicant_in_USD          1.000000          -0.116605    0.570909
#
#                    Loan_Amount_Term  Credit_History  Applicant_in_USD
# ApplicantIncome           -0.045306       -0.014715          1.000000
# CoapplicantIncome         -0.059878       -0.002056         -0.116605
# LoanAmount                 0.039447       -0.008433          0.570909
# Loan_Amount_Term           1.000000        0.001470         -0.045306
# Credit_History             0.001470        1.000000         -0.014715
# Applicant_in_USD          -0.045306       -0.014715          1.000000

# %%
x=a.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(x)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(x,cmap="Blues",annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(x,cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
del a["Applicant_in_USD"]

# %%
sns.catplot(data=a,x="Loan_Status",kind="count")

# %%
a["Loan_Status"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.catplot(data=a,x="Dependents",kind="count")

# %%
sns.catplot(data=a,x="Dependents",kind="count")

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=[20,5])
sns.histplot(a["ApplicantIncome"])
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='Count'>

# %%
plt.figure(figsize=[20,5])
sns.histplot(a["ApplicantIncome"])
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='Count'>

# %%
sns.jointplot(data=a,x="ApplicantIncome",y="LoanAmount",kind="scatter",hue="Loan_Status")

# %%
sns.jointplot(data=a,x="ApplicantIncome",y="LoanAmount",kind="reg")

# %%
sns.jointplot(data=a,x="ApplicantIncome",y="LoanAmount",kind="reg")

# %%
sns.pairplot(data=a,hue="Gender")

# %%
sns.catplot(data=a,x="ApplicantIncome",y="Gender")

# %%
sns.catplot(data=a,y="ApplicantIncome",x="Gender",kind="box")

# %%
sns.catplot(data=a,x="Gender",y="ApplicantIncome",kind="box",hue="Loan_Status")

# %%
sns.catplot(data=a,x="Gender",y="ApplicantIncome",kind="swarm",hue="Loan_Status")
# Out:
# C:\Users\RAJAT\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 61.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\RAJAT\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 22.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=a,x="Gender",y="ApplicantIncome",kind="violin",hue="Loan_Status")

# %%
sns.scatterplot(data=a,x="ApplicantIncome",y="LoanAmount",hue="Loan_Status")
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
sns.scatterplot(data=a,x="ApplicantIncome",y="LoanAmount",hue="Loan_Status",size=a["LoanAmount"])
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
import matplotlib.pyplot as plt
plt.plot(a["LoanAmount"],a["ApplicantIncome"])
